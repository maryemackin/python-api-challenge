# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install citipy
# Out:
# Collecting citipy
#   Using cached citipy-0.0.6-py3-none-any.whl
# Collecting kdtree>=0.12 (from citipy)
#   Downloading kdtree-0.16-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.6 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 636

# %% [markdown]
# ---

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=san francisco")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=f27b6614587941da959b0e70f7a6d5b8&q=san francisco

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | labrador city
# Processing Record 2 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | sao joao dos patos
# Processing Record 5 of Set 1 | cuyo
# Processing Record 6 of Set 1 | miquelon
# Processing Record 7 of Set 1 | saruhanli
# Processing Record 8 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 1 | afaahiti
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | uturoa
# Processing Record 13 of Set 1 | invercargill
# Processing Record 14 of Set 1 | fort bragg
# Processing Record 15 of Set 1 | troitsko-pechorsk
# Processing Record 16 of Set 1 | polyarnyy
# Processing Record 17 of Set 1 | margaret river
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | adamstown
# Processing Record 21 of Set 1 | hancheng
# Processing Record 22 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 23 of Set 1 | poronaysk
# Processing Record 24 of Set 1 | bilibino
# Processing Record 25 of Set 1 | edinburgh of the seven seas
# Processing Record 26 of Set 1 | port-aux-francais
# Processing Record 27 of Set 1 | margate
# Processing Record 28 of Set 1 | juan griego
# Processing Record 29 of Set 1 | mount isa
# Processing Record 30 of Set 1 | luang namtha
# Processing Record 31 of Set 1 | stanley
# Processing Record 32 of Set 1 | cadale
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | churapcha
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | kununurra
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | guijuelo
# Processing Record 39 of Set 1 | xining
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | tazovsky
# Processing Record 42 of Set 1 | ulsteinvik
# Processing Record 43 of Set 1 | tsiombe
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | castillos
# Processing Record 46 of Set 1 | udachny
# Processing Record 47 of Set 1 | mahibadhoo
# Processing Record 48 of Set 1 | terbanggi besar
# Processing Record 49 of Set 1 | otley
# Processing Record 50 of Set 1 | el fula
# City not found. Skipping...
# Processing Record 0 of Set 2 | klyuchi
# Processing Record 1 of Set 2 | al kharijah
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | umri
# Processing Record 6 of Set 2 | vallenar
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | puerto natales
# Processing Record 9 of Set 2 | woolgoolga
# Processing Record 10 of Set 2 | rikaze
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | port mathurin
# Processing Record 13 of Set 2 | kibaya
# Processing Record 14 of Set 2 | suva
# Processing Record 15 of Set 2 | buhe
# Processing Record 16 of Set 2 | shindand
# Processing Record 17 of Set 2 | remire-montjoly
# Processing Record 18 of Set 2 | bay roberts
# Processing Record 19 of Set 2 | isafjordur
# Processing Record 20 of Set 2 | turpan
# Processing Record 21 of Set 2 | verkhnevilyuysk
# Processing Record 22 of Set 2 | prince rupert
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | likiep
# Processing Record 25 of Set 2 | whitehorse
# Processing Record 26 of Set 2 | grand gaube
# Processing Record 27 of Set 2 | cockburn town
# Processing Record 28 of Set 2 | machina
# Processing Record 29 of Set 2 | agat village
# Processing Record 30 of Set 2 | alofi
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | hultsfred
# Processing Record 34 of Set 2 | christchurch
# Processing Record 35 of Set 2 | nasir
# Processing Record 36 of Set 2 | shwebo
# Processing Record 37 of Set 2 | kenai
# Processing Record 38 of Set 2 | aasiaat
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | caleta de carquin
# Processing Record 42 of Set 2 | ndele
# Processing Record 43 of Set 2 | pacasmayo
# Processing Record 44 of Set 2 | hasaki
# Processing Record 45 of Set 2 | tongouson
# Processing Record 46 of Set 2 | jinchang
# Processing Record 47 of Set 2 | muisne
# Processing Record 48 of Set 2 | hawaiian paradise park
# Processing Record 49 of Set 2 | mahajanga
# Processing Record 0 of Set 3 | papatowai
# Processing Record 1 of Set 3 | ramnicu sarat
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | monastir
# Processing Record 4 of Set 3 | wailua homesteads
# Processing Record 5 of Set 3 | glendive
# Processing Record 6 of Set 3 | cidade velha
# Processing Record 7 of Set 3 | anadyr
# Processing Record 8 of Set 3 | serang
# Processing Record 9 of Set 3 | skidaway island
# Processing Record 10 of Set 3 | vuktyl
# Processing Record 11 of Set 3 | callao
# Processing Record 12 of Set 3 | nieuw nickerie
# Processing Record 13 of Set 3 | kulu
# Processing Record 14 of Set 3 | frontera
# Processing Record 15 of Set 3 | embarcacion
# Processing Record 16 of Set 3 | san patricio
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | kulia village
# City not found. Skipping...
# Processing Record 19 of Set 3 | hengshui
# Processing Record 20 of Set 3 | badger
# Processing Record 21 of Set 3 | okhotsk
# Processing Record 22 of Set 3 | villa ojo de agua
# Processing Record 23 of Set 3 | atafu village
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | zheleznodorozhnyy
# Processing Record 26 of Set 3 | smithers
# Processing Record 27 of Set 3 | yilan
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | enriquillo
# Processing Record 30 of Set 3 | port lincoln
# Processing Record 31 of Set 3 | zheshart
# Processing Record 32 of Set 3 | dhidhdhoo
# Processing Record 33 of Set 3 | galliano
# Processing Record 34 of Set 3 | chapaev
# Processing Record 35 of Set 3 | brookings
# Processing Record 36 of Set 3 | parfino
# Processing Record 37 of Set 3 | kovdor
# Processing Record 38 of Set 3 | ola
# Processing Record 39 of Set 3 | bokhan
# Processing Record 40 of Set 3 | greenland
# Processing Record 41 of Set 3 | berrahal
# Processing Record 42 of Set 3 | balakhta
# Processing Record 43 of Set 3 | tartagal
# Processing Record 44 of Set 3 | chibougamau
# Processing Record 45 of Set 3 | makarov
# Processing Record 46 of Set 3 | gadzhiyevo
# Processing Record 47 of Set 3 | san antonio de pale
# Processing Record 48 of Set 3 | touros
# Processing Record 49 of Set 3 | west island
# Processing Record 0 of Set 4 | dunedin
# Processing Record 1 of Set 4 | roma
# Processing Record 2 of Set 4 | suicheng
# Processing Record 3 of Set 4 | chifeng
# Processing Record 4 of Set 4 | tolanaro
# Processing Record 5 of Set 4 | menomonie
# Processing Record 6 of Set 4 | ashburton
# Processing Record 7 of Set 4 | yaren
# Processing Record 8 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 9 of Set 4 | siuri
# Processing Record 10 of Set 4 | vila velha
# Processing Record 11 of Set 4 | jamestown
# Processing Record 12 of Set 4 | barbezieux-saint-hilaire
# Processing Record 13 of Set 4 | mabaruma
# Processing Record 14 of Set 4 | darab
# Processing Record 15 of Set 4 | kone
# Processing Record 16 of Set 4 | swakopmund
# Processing Record 17 of Set 4 | at taj
# Processing Record 18 of Set 4 | linxia chengguanzhen
# Processing Record 19 of Set 4 | mitu
# Processing Record 20 of Set 4 | chengde
# Processing Record 21 of Set 4 | zaragoza
# Processing Record 22 of Set 4 | saratamata
# City not found. Skipping...
# Processing Record 23 of Set 4 | ketchikan
# Processing Record 24 of Set 4 | senanga
# Processing Record 25 of Set 4 | priargunsk
# Processing Record 26 of Set 4 | cidreira
# Processing Record 27 of Set 4 | tura
# Processing Record 28 of Set 4 | paka
# Processing Record 29 of Set 4 | buka
# Processing Record 30 of Set 4 | fort stockton
# Processing Record 31 of Set 4 | boguchany
# Processing Record 32 of Set 4 | gamba
# Processing Record 33 of Set 4 | queenstown
# Processing Record 34 of Set 4 | howard springs
# Processing Record 35 of Set 4 | tawau
# Processing Record 36 of Set 4 | dehui
# Processing Record 37 of Set 4 | bel ombre
# Processing Record 38 of Set 4 | olonkinbyen
# Processing Record 39 of Set 4 | fortaleza
# Processing Record 40 of Set 4 | nagqu
# Processing Record 41 of Set 4 | borovskoy
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | aneho
# Processing Record 44 of Set 4 | la sarre
# Processing Record 45 of Set 4 | malvan
# Processing Record 46 of Set 4 | peace river
# Processing Record 47 of Set 4 | morro do chapeu
# Processing Record 48 of Set 4 | lerwick
# Processing Record 49 of Set 4 | obo
# Processing Record 0 of Set 5 | chinde
# Processing Record 1 of Set 5 | givors
# Processing Record 2 of Set 5 | an ros
# Processing Record 3 of Set 5 | swift current
# Processing Record 4 of Set 5 | deneysville
# Processing Record 5 of Set 5 | haiku-pauwela
# Processing Record 6 of Set 5 | acapulco de juarez
# Processing Record 7 of Set 5 | mejit
# Processing Record 8 of Set 5 | constantia
# Processing Record 9 of Set 5 | tosontsengel
# Processing Record 10 of Set 5 | ilomantsi
# Processing Record 11 of Set 5 | tchintabaraden
# Processing Record 12 of Set 5 | hakui
# Processing Record 13 of Set 5 | oeiras
# Processing Record 14 of Set 5 | utrik
# Processing Record 15 of Set 5 | zhangye
# Processing Record 16 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 17 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 18 of Set 5 | mugia
# Processing Record 19 of Set 5 | kirensk
# Processing Record 20 of Set 5 | ifo
# Processing Record 21 of Set 5 | san juan de uraba
# Processing Record 22 of Set 5 | shimoda
# Processing Record 23 of Set 5 | bardai
# Processing Record 24 of Set 5 | praia da vitoria
# Processing Record 25 of Set 5 | qaqortoq
# Processing Record 26 of Set 5 | tongchuanshi
# Processing Record 27 of Set 5 | posse
# Processing Record 28 of Set 5 | lindisfarne
# Processing Record 29 of Set 5 | idri
# Processing Record 30 of Set 5 | ares
# Processing Record 31 of Set 5 | mirnyy
# Processing Record 32 of Set 5 | takoradi
# Processing Record 33 of Set 5 | kampene
# Processing Record 34 of Set 5 | talnakh
# Processing Record 35 of Set 5 | al ghayzah
# Processing Record 36 of Set 5 | nove straseci
# Processing Record 37 of Set 5 | kifri
# Processing Record 38 of Set 5 | vrutky
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | neiafu
# Processing Record 41 of Set 5 | tofol
# Processing Record 42 of Set 5 | khandyga
# Processing Record 43 of Set 5 | sapele
# Processing Record 44 of Set 5 | mount gambier
# Processing Record 45 of Set 5 | ulverstone
# Processing Record 46 of Set 5 | parras de la fuente
# Processing Record 47 of Set 5 | iquitos
# Processing Record 48 of Set 5 | ciudad altamirano
# Processing Record 49 of Set 5 | herriman
# Processing Record 0 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 6 | eagle pass
# Processing Record 2 of Set 6 | la villa del rosario
# Processing Record 3 of Set 6 | borba
# Processing Record 4 of Set 6 | ada
# Processing Record 5 of Set 6 | kuqa
# Processing Record 6 of Set 6 | inongo
# Processing Record 7 of Set 6 | baharly
# Processing Record 8 of Set 6 | ebon
# Processing Record 9 of Set 6 | lihue
# Processing Record 10 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 11 of Set 6 | mongar
# Processing Record 12 of Set 6 | berlin
# Processing Record 13 of Set 6 | sar-e pul
# Processing Record 14 of Set 6 | bela
# Processing Record 15 of Set 6 | freeport
# Processing Record 16 of Set 6 | nemuro
# Processing Record 17 of Set 6 | rabigh
# Processing Record 18 of Set 6 | mil'kovo
# Processing Record 19 of Set 6 | college
# Processing Record 20 of Set 6 | bokoro
# Processing Record 21 of Set 6 | jalai nur
# Processing Record 22 of Set 6 | mountain home
# Processing Record 23 of Set 6 | pitimbu
# Processing Record 24 of Set 6 | ust-nera
# Processing Record 25 of Set 6 | arawa
# Processing Record 26 of Set 6 | buala
# Processing Record 27 of Set 6 | mossel bay
# Processing Record 28 of Set 6 | guerrero negro
# Processing Record 29 of Set 6 | ascension
# Processing Record 30 of Set 6 | fada n'gourma
# Processing Record 31 of Set 6 | revda
# Processing Record 32 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 33 of Set 6 | arraial do cabo
# Processing Record 34 of Set 6 | nova sintra
# Processing Record 35 of Set 6 | balimila
# Processing Record 36 of Set 6 | betio village
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | minacu
# City not found. Skipping...
# Processing Record 39 of Set 6 | palikir - national government center
# Processing Record 40 of Set 6 | east london
# Processing Record 41 of Set 6 | yuzhno-kurilsk
# Processing Record 42 of Set 6 | bikenibeu village
# Processing Record 43 of Set 6 | altay
# Processing Record 44 of Set 6 | gizo
# Processing Record 45 of Set 6 | taltal
# Processing Record 46 of Set 6 | kirgiz-miyaki
# Processing Record 47 of Set 6 | kidal
# Processing Record 48 of Set 6 | ghanzi
# Processing Record 49 of Set 6 | kodinsk
# Processing Record 0 of Set 7 | semenivka
# Processing Record 1 of Set 7 | tamanrasset
# Processing Record 2 of Set 7 | tevragh zeina
# City not found. Skipping...
# Processing Record 3 of Set 7 | aripuana
# Processing Record 4 of Set 7 | sisimiut
# Processing Record 5 of Set 7 | hechuan
# Processing Record 6 of Set 7 | tchollire
# Processing Record 7 of Set 7 | port alfred
# Processing Record 8 of Set 7 | severobaykal'sk
# Processing Record 9 of Set 7 | cestos city
# Processing Record 10 of Set 7 | kavaratti
# Processing Record 11 of Set 7 | kudahuvadhoo
# Processing Record 12 of Set 7 | howrah
# Processing Record 13 of Set 7 | eksel
# Processing Record 14 of Set 7 | magadan
# Processing Record 15 of Set 7 | sake
# Processing Record 16 of Set 7 | xingcheng
# Processing Record 17 of Set 7 | solleftea
# Processing Record 18 of Set 7 | vadso
# Processing Record 19 of Set 7 | lazaro cardenas
# Processing Record 20 of Set 7 | tabas
# Processing Record 21 of Set 7 | san andres
# Processing Record 22 of Set 7 | champerico
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | murashi
# Processing Record 25 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 26 of Set 7 | new norfolk
# Processing Record 27 of Set 7 | newman
# Processing Record 28 of Set 7 | luderitz
# Processing Record 29 of Set 7 | san luis de la loma
# Processing Record 30 of Set 7 | goondiwindi
# Processing Record 31 of Set 7 | sitka
# Processing Record 32 of Set 7 | nabire
# Processing Record 33 of Set 7 | strelka
# Processing Record 34 of Set 7 | san martin de los andes
# Processing Record 35 of Set 7 | vernon
# Processing Record 36 of Set 7 | nouna
# Processing Record 37 of Set 7 | sinabang
# Processing Record 38 of Set 7 | madison
# Processing Record 39 of Set 7 | hafar al-batin
# Processing Record 40 of Set 7 | totness
# Processing Record 41 of Set 7 | hampton bays
# Processing Record 42 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 43 of Set 7 | laayoune plage
# City not found. Skipping...
# Processing Record 44 of Set 7 | gaiman
# Processing Record 45 of Set 7 | pimentel
# Processing Record 46 of Set 7 | extrema
# Processing Record 47 of Set 7 | kingston
# Processing Record 48 of Set 7 | toktogul
# Processing Record 49 of Set 7 | greater sudbury
# Processing Record 0 of Set 8 | nguigmi
# Processing Record 1 of Set 8 | kudat
# Processing Record 2 of Set 8 | vizinga
# Processing Record 3 of Set 8 | flying fish cove
# Processing Record 4 of Set 8 | kaoma
# Processing Record 5 of Set 8 | uruacu
# Processing Record 6 of Set 8 | colonia
# Processing Record 7 of Set 8 | vorgashor
# Processing Record 8 of Set 8 | caetite
# Processing Record 9 of Set 8 | island harbour
# Processing Record 10 of Set 8 | naha
# Processing Record 11 of Set 8 | takaungu
# Processing Record 12 of Set 8 | hotan
# Processing Record 13 of Set 8 | enewetak
# Processing Record 14 of Set 8 | tete
# Processing Record 15 of Set 8 | san pedro pochutla
# Processing Record 16 of Set 8 | broome
# Processing Record 17 of Set 8 | kenora
# Processing Record 18 of Set 8 | nantucket
# Processing Record 19 of Set 8 | sangolqui
# Processing Record 20 of Set 8 | novyy urgal
# Processing Record 21 of Set 8 | hermanus
# Processing Record 22 of Set 8 | tommot
# Processing Record 23 of Set 8 | scottburgh
# Processing Record 24 of Set 8 | iskateley
# Processing Record 25 of Set 8 | garoua boulai
# Processing Record 26 of Set 8 | togur
# Processing Record 27 of Set 8 | pamandzi
# Processing Record 28 of Set 8 | bamboo flat
# Processing Record 29 of Set 8 | dryden
# Processing Record 30 of Set 8 | sarlat-la-caneda
# Processing Record 31 of Set 8 | lugovoy
# Processing Record 32 of Set 8 | kataragama
# City not found. Skipping...
# Processing Record 33 of Set 8 | port isabel
# Processing Record 34 of Set 8 | sao joao batista
# Processing Record 35 of Set 8 | raseiniai
# Processing Record 36 of Set 8 | markapur
# Processing Record 37 of Set 8 | orange beach
# Processing Record 38 of Set 8 | elmendorf air force base
# City not found. Skipping...
# Processing Record 39 of Set 8 | anabar
# City not found. Skipping...
# Processing Record 40 of Set 8 | tiruchchendur
# Processing Record 41 of Set 8 | okha
# Processing Record 42 of Set 8 | nuku'alofa
# Processing Record 43 of Set 8 | codo
# Processing Record 44 of Set 8 | yatou
# Processing Record 45 of Set 8 | kerikeri
# Processing Record 46 of Set 8 | kourou
# Processing Record 47 of Set 8 | daru
# Processing Record 48 of Set 8 | syktyvkar
# Processing Record 49 of Set 8 | keflavik
# Processing Record 0 of Set 9 | uxbridge
# Processing Record 1 of Set 9 | waddan
# Processing Record 2 of Set 9 | codrington
# Processing Record 3 of Set 9 | antsohihy
# Processing Record 4 of Set 9 | kumylzhenskaya
# Processing Record 5 of Set 9 | rebola
# Processing Record 6 of Set 9 | geraldton
# Processing Record 7 of Set 9 | hoxtolgay
# City not found. Skipping...
# Processing Record 8 of Set 9 | vredenburg
# City not found. Skipping...
# Processing Record 9 of Set 9 | faya-largeau
# Processing Record 10 of Set 9 | saudarkrokur
# Processing Record 11 of Set 9 | midvagur
# Processing Record 12 of Set 9 | tobruk
# Processing Record 13 of Set 9 | dubai
# Processing Record 14 of Set 9 | berezovyy
# Processing Record 15 of Set 9 | vila franca do campo
# Processing Record 16 of Set 9 | lodwar
# Processing Record 17 of Set 9 | jand
# Processing Record 18 of Set 9 | katsuura
# Processing Record 19 of Set 9 | balvi
# Processing Record 20 of Set 9 | vyazemskiy
# Processing Record 21 of Set 9 | puerto madero
# Processing Record 22 of Set 9 | macas
# Processing Record 23 of Set 9 | portland
# Processing Record 24 of Set 9 | sabang
# Processing Record 25 of Set 9 | sarupathar
# Processing Record 26 of Set 9 | kas
# Processing Record 27 of Set 9 | n'zeto
# Processing Record 28 of Set 9 | haenam
# Processing Record 29 of Set 9 | filadelfia
# Processing Record 30 of Set 9 | labuan lombok
# City not found. Skipping...
# Processing Record 31 of Set 9 | aracati
# Processing Record 32 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 33 of Set 9 | redencao
# Processing Record 34 of Set 9 | puerto baquerizo moreno
# Processing Record 35 of Set 9 | musay'id
# City not found. Skipping...
# Processing Record 36 of Set 9 | santiago de cao
# Processing Record 37 of Set 9 | ustka
# Processing Record 38 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 39 of Set 9 | illizi
# Processing Record 40 of Set 9 | al hazm
# Processing Record 41 of Set 9 | shingu
# Processing Record 42 of Set 9 | greenville
# Processing Record 43 of Set 9 | viedma
# Processing Record 44 of Set 9 | kongolo
# Processing Record 45 of Set 9 | egilsstadir
# Processing Record 46 of Set 9 | chilakalurupet
# Processing Record 47 of Set 9 | djambala
# Processing Record 48 of Set 9 | merizo village
# Processing Record 49 of Set 9 | sungai penuh
# Processing Record 0 of Set 10 | rivne
# Processing Record 1 of Set 10 | progreso
# Processing Record 2 of Set 10 | forster
# Processing Record 3 of Set 10 | fort st. john
# Processing Record 4 of Set 10 | male
# Processing Record 5 of Set 10 | georgetown
# Processing Record 6 of Set 10 | hadibu
# Processing Record 7 of Set 10 | lata
# Processing Record 8 of Set 10 | mbanza kongo
# Processing Record 9 of Set 10 | antonio enes
# Processing Record 10 of Set 10 | matoury
# Processing Record 11 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 10 | askoy
# Processing Record 13 of Set 10 | tamandare
# Processing Record 14 of Set 10 | alice springs
# Processing Record 15 of Set 10 | lithgow
# Processing Record 16 of Set 10 | vilyuchinsk
# Processing Record 17 of Set 10 | sao vicente
# Processing Record 18 of Set 10 | ta`u
# Processing Record 19 of Set 10 | alo
# Processing Record 20 of Set 10 | mananjary
# Processing Record 21 of Set 10 | crane
# Processing Record 22 of Set 10 | holbrook
# Processing Record 23 of Set 10 | bongor
# Processing Record 24 of Set 10 | alta
# Processing Record 25 of Set 10 | zara
# Processing Record 26 of Set 10 | putian
# Processing Record 27 of Set 10 | kharkhorin
# Processing Record 28 of Set 10 | st. john's
# Processing Record 29 of Set 10 | saipan
# Processing Record 30 of Set 10 | gransee
# Processing Record 31 of Set 10 | jeddah
# Processing Record 32 of Set 10 | druzhkivka
# Processing Record 33 of Set 10 | solnechnyy
# Processing Record 34 of Set 10 | sola
# Processing Record 35 of Set 10 | posto fiscal rolim de moura
# Processing Record 36 of Set 10 | porto novo
# Processing Record 37 of Set 10 | safi
# Processing Record 38 of Set 10 | cozumel
# Processing Record 39 of Set 10 | dakhla
# Processing Record 40 of Set 10 | miramar beach
# Processing Record 41 of Set 10 | lorain
# Processing Record 42 of Set 10 | sanming
# Processing Record 43 of Set 10 | happy valley-goose bay
# Processing Record 44 of Set 10 | cayce
# Processing Record 45 of Set 10 | kargasok
# Processing Record 46 of Set 10 | salaga
# Processing Record 47 of Set 10 | cam pha mines
# Processing Record 48 of Set 10 | al jawf
# Processing Record 49 of Set 10 | severo-yeniseyskiy
# Processing Record 0 of Set 11 | yeed
# Processing Record 1 of Set 11 | poyang
# Processing Record 2 of Set 11 | pariaman
# Processing Record 3 of Set 11 | pont rouge
# Processing Record 4 of Set 11 | opuwo
# Processing Record 5 of Set 11 | ba
# City not found. Skipping...
# Processing Record 6 of Set 11 | santo augusto
# Processing Record 7 of Set 11 | arkhangel'sk
# Processing Record 8 of Set 11 | tangalle
# Processing Record 9 of Set 11 | arteche
# Processing Record 10 of Set 11 | jequie
# Processing Record 11 of Set 11 | oliver
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | yarovoye
# Processing Record 14 of Set 11 | nahiyat ash shinafiyah
# Processing Record 15 of Set 11 | tatarka
# Processing Record 16 of Set 11 | chasong
# Processing Record 17 of Set 11 | maragogi
# Processing Record 18 of Set 11 | susuman
# Processing Record 19 of Set 11 | grand baie
# Processing Record 20 of Set 11 | smach mean chey
# City not found. Skipping...
# Processing Record 21 of Set 11 | meraux
# Processing Record 22 of Set 11 | augusto correa
# Processing Record 23 of Set 11 | fale old settlement
# Processing Record 24 of Set 11 | fort mcmurray
# Processing Record 25 of Set 11 | broken hill
# Processing Record 26 of Set 11 | horta
# Processing Record 27 of Set 11 | albertina
# Processing Record 28 of Set 11 | jackson
# Processing Record 29 of Set 11 | biga
# Processing Record 30 of Set 11 | kolonia
# Processing Record 31 of Set 11 | nar'yan-mar
# Processing Record 32 of Set 11 | auki
# Processing Record 33 of Set 11 | medicine hat
# Processing Record 34 of Set 11 | glucksburg
# Processing Record 35 of Set 11 | nuuk
# Processing Record 36 of Set 11 | tubarjal
# Processing Record 37 of Set 11 | alto barinas
# Processing Record 38 of Set 11 | svishtov
# Processing Record 39 of Set 11 | nyagan
# Processing Record 40 of Set 11 | pisco
# Processing Record 41 of Set 11 | lionel town
# Processing Record 42 of Set 11 | taoudenni
# Processing Record 43 of Set 11 | hovd
# Processing Record 44 of Set 11 | port saint john's
# Processing Record 45 of Set 11 | kalemie
# Processing Record 46 of Set 11 | robit
# Processing Record 47 of Set 11 | rufino
# Processing Record 48 of Set 11 | sudislavl'
# Processing Record 49 of Set 11 | mar del plata
# Processing Record 0 of Set 12 | petauke
# Processing Record 1 of Set 12 | ulladulla
# Processing Record 2 of Set 12 | namsos
# Processing Record 3 of Set 12 | carneys point
# Processing Record 4 of Set 12 | tionk essil
# Processing Record 5 of Set 12 | qashyr
# Processing Record 6 of Set 12 | san lawrenz
# Processing Record 7 of Set 12 | oualidia
# City not found. Skipping...
# Processing Record 8 of Set 12 | plastun
# Processing Record 9 of Set 12 | katsuren-haebaru
# Processing Record 10 of Set 12 | visby
# Processing Record 11 of Set 12 | mount pearl
# Processing Record 12 of Set 12 | guatire
# Processing Record 13 of Set 12 | nchelenge
# Processing Record 14 of Set 12 | kabompo
# Processing Record 15 of Set 12 | maturin
# Processing Record 16 of Set 12 | nadi
# Processing Record 17 of Set 12 | atherton
# Processing Record 18 of Set 12 | holualoa
# Processing Record 19 of Set 12 | lexington
# Processing Record 20 of Set 12 | palembang
# Processing Record 21 of Set 12 | valle de la pascua
# Processing Record 22 of Set 12 | zapala
# Processing Record 23 of Set 12 | colonel hill
# Processing Record 24 of Set 12 | mana
# Processing Record 25 of Set 12 | kuching
# Processing Record 26 of Set 12 | arafat
# Processing Record 27 of Set 12 | wynyard
# Processing Record 28 of Set 12 | concepcion
# Processing Record 29 of Set 12 | sattahip
# Processing Record 30 of Set 12 | dauphin
# Processing Record 31 of Set 12 | nadym
# Processing Record 32 of Set 12 | pallippatti
# Processing Record 33 of Set 12 | sofo-birnin-gwari
# Processing Record 34 of Set 12 | bolgatanga
# Processing Record 35 of Set 12 | genhe
# Processing Record 36 of Set 12 | kansk
# Processing Record 37 of Set 12 | shimla
# Processing Record 38 of Set 12 | ad darb
# Processing Record 39 of Set 12 | kailua-kona
# Processing Record 40 of Set 12 | santana
# Processing Record 41 of Set 12 | asubulaq
# Processing Record 42 of Set 12 | beau vallon
# Processing Record 43 of Set 12 | aswan
# Processing Record 44 of Set 12 | taroa
# Processing Record 45 of Set 12 | fisterra
# Processing Record 46 of Set 12 | davlekanovo
# Processing Record 47 of Set 12 | colonia menno
# Processing Record 48 of Set 12 | minas de marcona
# Processing Record 49 of Set 12 | murud
# Processing Record 0 of Set 13 | porto velho
# Processing Record 1 of Set 13 | soe
# Processing Record 2 of Set 13 | port glaud
# City not found. Skipping...
# Processing Record 3 of Set 13 | turtas
# Processing Record 4 of Set 13 | sorong
# Processing Record 5 of Set 13 | pasighat
# Processing Record 6 of Set 13 | kayangel
# Processing Record 7 of Set 13 | kafanchan
# Processing Record 8 of Set 13 | igrim
# Processing Record 9 of Set 13 | katrineholm
# Processing Record 10 of Set 13 | saint-joseph
# Processing Record 11 of Set 13 | kharp
# Processing Record 12 of Set 13 | pierre
# Processing Record 13 of Set 13 | la passe
# Processing Record 14 of Set 13 | smara
# Processing Record 15 of Set 13 | cururupu
# Processing Record 16 of Set 13 | nkurenkuru
# City not found. Skipping...
# Processing Record 17 of Set 13 | cooper's town
# Processing Record 18 of Set 13 | nobeoka
# Processing Record 19 of Set 13 | lerma
# Processing Record 20 of Set 13 | vingt cinq
# City not found. Skipping...
# Processing Record 21 of Set 13 | kyakhta
# Processing Record 22 of Set 13 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 23 of Set 13 | bulayevo
# Processing Record 24 of Set 13 | jerada
# Processing Record 25 of Set 13 | morehead city
# Processing Record 26 of Set 13 | tual
# Processing Record 27 of Set 13 | bucerias
# Processing Record 28 of Set 13 | kapuskasing
# Processing Record 29 of Set 13 | bodmin
# Processing Record 30 of Set 13 | kamikawa
# Processing Record 31 of Set 13 | vorkuta
# Processing Record 32 of Set 13 | gunjur
# Processing Record 33 of Set 13 | melekeok village
# Processing Record 34 of Set 13 | pagsanghan
# Processing Record 35 of Set 13 | salaverry
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 12 | nsanje
# Processing Record 15 of Set 12 | xuchang
# Processing Record 16 of Set 12 | todos santos
# Processing Record 17 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 18 of Set 12 | bataipora
# Processing Record 19 of Set 12 | tateyama
# Processing Record 20 of Set 12 | wajima
# Processing Record 21 of Set 12 | pokosnoye
# Processing Record 22 of Set 12 | waipawa
# Processing Record 23 of Set 12 | yaring
# Processing Record 24 of Set 12 | isiro
# Processing Record 25 of Set 12 | chivilcoy
# Processing Record 26 of Set 12 | mandalgovi
# Processing Record 27 of Set 12 | nicoya
# Processing Record 28 of Set 12 | novocheremshansk
# Processing Record 29 of Set 12 | emirdag
# Processing Record 30 of Set 12 | nouadhibou
# Processing Record 31 of Set 12 | tongliao
# Processing Record 32 of Set 12 | ryomgard
# Processing Record 33 of Set 12 | khudumelapye
# Processing Record 34 of Set 12 | talcahuano
# Processing Record 35 of Set 12 | gifhorn
# Processing Record 36 of Set 12 | bilma
# Processing Record 37 of Set 12 | vung tau
# Processing Record 38 of Set 12 | byron bay
# Processing Record 39 of Set 12 | kalabo
# Processing Record 40 of Set 12 | arcata
# Processing Record 41 of Set 12 | lemoore
# Processing Record 42 of Set 12 | norfolk
# Processing Record 43 of Set 12 | juba
# Processing Record 44 of Set 12 | pali
# Processing Record 45 of Set 12 | katsuura
# Processing Record 46 of Set 12 | bambanglipuro
# Processing Record 47 of Set 12 | padang
# Processing Record 48 of Set 12 | freeport
# Processing Record 49 of Set 12 | bulgan
# Processing Record 0 of Set 13 | sorland
# Processing Record 1 of Set 13 | saryg-sep
# Processing Record 2 of Set 13 | batagay-alyta
# Processing Record 3 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 13 | lompoc
# Processing Record 5 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | changli
# Processing Record 7 of Set 13 | choma
# Processing Record 8 of Set 13 | tena
# Processing Record 9 of Set 13 | ilhabela
# Processing Record 10 of Set 13 | redmond
# Processing Record 11 of Set 13 | wyndham
# Processing Record 12 of Set 13 | nhulunbuy
# Processing Record 13 of Set 13 | sangamner
# Processing Record 14 of Set 13 | road town
# Processing Record 15 of Set 13 | ranong
# Processing Record 16 of Set 13 | staryy nadym
# Processing Record 17 of Set 13 | dargaville
# Processing Record 18 of Set 13 | sovetskiy
# Processing Record 19 of Set 13 | tatarsk
# Processing Record 20 of Set 13 | canchungo
# Processing Record 21 of Set 13 | iquique
# Processing Record 22 of Set 13 | poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          603
# Lat           603
# Lng           603
# Max Temp      603
# Humidity      603
# Cloudiness    603
# Wind Speed    603
# Country       603
# Date          603
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       labrador city  52.9463  -66.9114      1.26        97         100
# 1            waitangi -43.9535 -176.5597     12.96        74          40
# 2  sao joao dos patos  -6.4950  -43.7022     24.23        72         100
# 3                cuyo  10.8525  121.0086     29.98        73         100
# 4            miquelon  47.0975  -56.3814      2.29        79          76
#
#    Wind Speed Country        Date
# 0        4.73      CA  1714275010
# 1        7.33      NZ  1714275084
# 2        1.10      BR  1714275085
# 3        2.88      PH  1714275085
# 4        6.61      PM  1714275085

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0             labrador city  52.9463  -66.9114      1.26        97
# 1                  waitangi -43.9535 -176.5597     12.96        74
# 2        sao joao dos patos  -6.4950  -43.7022     24.23        72
# 3                      cuyo  10.8525  121.0086     29.98        73
# 4                  miquelon  47.0975  -56.3814      2.29        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        4.73      CA  1714275010
# 1                40        7.33      NZ  1714275084
# 2               100        1.10      BR  1714275085
# 3               100        2.88      PH  1714275085
# 4                76        6.61      PM  1714275085

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="blue",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Temperature (s) {str(time.strftime('%y-%m-%d'))}")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (c)")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="orange",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="red",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="yellow",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (kph)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):

    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_equation = f"y = {round(slope,2)}x + {round(intercept,2)}"

    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df[city_data_df["Lat"] >=0])

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        labrador city  52.9463  -66.9114      1.26        97         100
# 3                 cuyo  10.8525  121.0086     29.98        73         100
# 4             miquelon  47.0975  -56.3814      2.29        79          76
# 5            saruhanli  38.7346   27.5681     12.00        83           1
# 11          fort bragg  35.1390  -79.0060     17.44        78         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.73      CA  1714275010
# 3              2.88      PH  1714275085
# 4              6.61      PM  1714275085
# 5              1.81      TR  1714275085
# 11             4.02      US  1714275086

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df[city_data_df["Lat"] < 0])

# Display sample data
southern_hemi_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                  waitangi -43.9535 -176.5597     12.96        74
# 2        sao joao dos patos  -6.4950  -43.7022     24.23        72
# 6                  afaahiti -17.7500 -149.2833     25.95        82
# 7              punta arenas -53.1500  -70.9167      2.45        75
# 8                   ushuaia -54.8000  -68.3000      1.27        95
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                40        7.33      NZ  1714275084
# 2               100        1.10      BR  1714275085
# 6                80        9.88      PF  1714275085
# 7                68       10.98      CL  1714275086
# 8                99        4.53      AR  1714275086

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):

    # Compute Linear Regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=14, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)

# %%
# Linear regression on Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Max Temp"]
plot_linear_regression(x_value, y_value, "Max Temp", (6, -10))
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Max Temp"]
plot_linear_regression(x_value, y_value, "Max Temp", (-55, 27))
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Humidity"]
plot_linear_regression(x_value, y_value, "Humidity", (50, 10))
plt.show()

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Humidity"]
plot_linear_regression(x_value, y_value, "Humidity", (-55, 20))
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_value, y_value, "Cloudiness", (52, 31))
plt.show()

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_value, y_value, "Cloudiness", (-55, 30))
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_value, y_value, "Wind Speed", (50, 10))
plt.show()

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_value, y_value, "Wind Speed", (-25, 15))
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
