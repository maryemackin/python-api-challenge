# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install citipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 608

# %% [markdown]
# ---

# %%
# test key and get data structure
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=san francisco")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=f27b6614587941da959b0e70f7a6d5b8&q=san francisco

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | guerrero negro
# Processing Record 3 of Set 1 | vilyuchinsk
# Processing Record 4 of Set 1 | malangali
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | west island
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | adamstown
# Processing Record 10 of Set 1 | isafjordur
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 13 of Set 1 | ust-nera
# Processing Record 14 of Set 1 | nanganga
# Processing Record 15 of Set 1 | harstad
# Processing Record 16 of Set 1 | sinabang
# Processing Record 17 of Set 1 | klyuchi
# Processing Record 18 of Set 1 | warmbaths
# Processing Record 19 of Set 1 | rongelap
# Processing Record 20 of Set 1 | alofi
# ...

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                     waitangi -43.9535 -176.5597     14.34        95
# 1               guerrero negro  27.9769 -114.0611     19.90        54
# 2                  vilyuchinsk  52.9306  158.4028      2.15        75
# 3                    malangali  -8.5667   34.8500     17.45        86
# 4  edinburgh of the seven seas -37.0676  -12.3116     13.40        72
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        3.13      NZ  1714503877
# 1          92        4.21      MX  1714503877
# 2           3        5.11      RU  1714503877
# 3          32        5.02      TZ  1714503877
# 4         100       13.36      SH  1714503878

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           waitangi -43.9535 -176.5597     14.34        95
# 1                     guerrero negro  27.9769 -114.0611     19.90        54
# 2                        vilyuchinsk  52.9306  158.4028      2.15        75
# 3                          malangali  -8.5667   34.8500     17.45        86
# 4        edinburgh of the seven seas -37.0676  -12.3116     13.40        72
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.13      NZ  1714503877
# 1                92        4.21      MX  1714503877
# 2                 3        5.11      RU  1714503877
# 3                32        5.02      TZ  1714503877
# 4               100       13.36      SH  1714503878

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="blue",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Temperature {str(time.strftime('%y-%m-%d'))}")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (c)")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="orange",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="red",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="yellow",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed {str(time.strftime('%Y-%m-%d'))}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (kph)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):

    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_equation = f"y = {round(slope,2)}x + {round(intercept,2)}"

    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = pd.DataFrame(city_data_df[city_data_df["Lat"] >=0])

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        guerrero negro  27.9769 -114.0611     19.90        54          92
# 2           vilyuchinsk  52.9306  158.4028      2.15        75           3
# 9            isafjordur  66.0755  -23.1240      5.02        75         100
# 11             ust-nera  64.5667  143.2000    -11.65        98         100
# 13              harstad  68.7990   16.5293      6.20        87          95
#
#          Wind Speed Country        Date
# City_ID
# 1              4.21      MX  1714503877
# 2              5.11      RU  1714503877
# 9              3.60      IS  1714503878
# 11             2.21      RU  1714503879
# 13             1.34      NO  1714503879

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = pd.DataFrame(city_data_df[city_data_df["Lat"] < 0])

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           waitangi -43.9535 -176.5597     14.34        95
# 3                          malangali  -8.5667   34.8500     17.45        86
# 4        edinburgh of the seven seas -37.0676  -12.3116     13.40        72
# 5                         codrington -38.2667  141.9667     13.31        74
# 6                        west island -12.1568   96.8225     27.99        89
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.13      NZ  1714503877
# 3                32        5.02      TZ  1714503877
# 4               100       13.36      SH  1714503878
# 5               100        6.95      AU  1714503878
# 6                75        3.09      CC  1714503878

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):

    # Compute Linear Regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=14, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")

# %%
# Linear regression on Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Max Temp"]
plot_linear_regression(x_value, y_value, "Max Temp", (6, -10))
# Out:
# The r-value is 0.7005868397716674

# %%
# Linear regression on Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Max Temp"]
plot_linear_regression(x_value, y_value, "Max Temp", (-55, 27))
plt.show()
# Out:
# The r-value is 0.5743068187066872

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere:
# - With a calculated r-value of 0.701, the data show a strong negative correlation between temperature and latitude , e.g. the temperature decreases as the latitude increases and vice versa
#
# Southern Hemisphere:
# - With a calculated r-value of 0.574 the data show a positive correlation between temperature and latitude, e.g. the temperature increases as the latitude increases and vice versa

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Humidity"]
plot_linear_regression(x_value, y_value, "Humidity", (50, 10))
plt.show()
# Out:
# The r-value is 0.054957683190787414

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Humidity"]
plot_linear_regression(x_value, y_value, "Humidity", (-55, 20))
plt.show()
# Out:
# The r-value is 0.026171337665867756

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere:
# - With a calculated r-value of 0.055, the data show a weak positive correlation between humidity and latitude, e.g. the humidity increases as the latitude increases and vice versa
#
# Southern Hemisphere:
# - With a calculated r-value of 0.026, the data show a weak positive correlation between humidity and latitude, e.g. the humidity increases as the latitude increases and vice versa

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_value, y_value, "Cloudiness", (52, 31))
plt.show()
# Out:
# The r-value is 0.005286671283808226

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_value, y_value, "Cloudiness", (-55, 30))
plt.show()
# Out:
# The r-value is 0.038411511080945294

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere:
# - With a calculated r-value of 0.005, the data show no correlation between cloudiness and latitude
#
# Southern Hemisphere:
# - With a calculated r-value of 0.005, the data show no correlation between cloudiness and latitude

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value = northern_hemi_df["Lat"]
y_value = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_value, y_value, "Wind Speed", (50, 10))
plt.show()
# Out:
# The r-value is 0.007843441977687235

# %%
# Southern Hemisphere
x_value = southern_hemi_df["Lat"]
y_value = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_value, y_value, "Wind Speed", (-25, 15))
plt.show()
# Out:
# The r-value is 0.10535089969080838

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Northern Hemisphere:
# - With a calculated r-value of 0.008, the data show no correlation between wind speed and latitude
#
# Southern Hemisphere:
# - With a calculated r-value of 0.105, the data show a slight negative correlation between wind speed and latitude, e.g. the wind speed decreases as the latitude increases and vice versa

# %% [markdown]
# **Analysis:**
# - The data indicate that both temperature and humidity are both affected by latitude while wind speed and cloudiness show little to no correlation to latitude
# - We would expect the wind speed vs latitude would be simmerlarly correlated as some of the fastest winds on earth have been recorded in both the north and south polar regions (per guinnes book of world records), but this is not what the data indicate
# -- More data points may be needed to accurately analyze this correlation
